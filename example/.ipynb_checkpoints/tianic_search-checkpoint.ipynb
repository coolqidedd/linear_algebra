# %% [markdown]
# # 泰坦尼克号—生还几率与(客舱等级、性别、年纪)的关系调查分析

# %% [markdown]
# ## 一、准备工作
# 从 https://www.kaggle.com/c/titanic/data 获取样本数据集
#
# ## 二、分析简介
# 此数据仅仅包含泰坦尼克号上 2224 名乘客和船员中的 891 名的数据
# ### 分析目标
# 生还几率与(客舱等级、性别、年纪)的关系

# %% [markdown]
# ## 三、样本数据初始化
# ### 1.加载样本数据

# %%
# -*- coding: utf-8 -*- 

# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline


# 读取原始数据    
original_data = pd.read_csv("titanic-data.csv");
print('共计12个变量:')
original_data.info()
# Out:
# 共计12个变量:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### 2. 样本变量与数据字典

# %% [markdown]
# Age | Cabin | Embarked | Fare | Name | Parch | PassengerId | Pclass | Sex | SibSp | Survived | Ticket
# ----|----|----|----|----| ----| ----| ----|----| ----|----|----|
# 年龄| 舱号 |出发港|票价|姓名| 同行的父母/孩子（人数） | 乘客ID | 舱等 |性别| 同行的兄弟姐妹/配偶（人数） | 是否生还 | 票号
#
# 港口 |
# ----|----|----|
# C = Cherbourg | Q = Queenstown | S = Southampton |
#
# 生还 |
# ----|----|
# 0 = 未生还 | 1 = 生还

# %% [markdown]
# ### 3.样本数据清理
# 数据清洗主要是删除原始数据中的无关数据、重复数据，平滑噪声数据，筛选掉与主题无关的数据，处理异常值、缺失值等。

# %% [markdown]
# #### 3.1.剔除不需要的变量

# %%
#只运行一次
print('只保留所需的5个变量:')
original_data.drop('PassengerId', axis=1, inplace=True)
original_data.drop('SibSp', axis=1, inplace=True)
original_data.drop('Parch', axis=1, inplace=True)
original_data.drop('Ticket', axis=1, inplace=True)
original_data.drop('Fare', axis=1, inplace=True)
original_data.drop('Cabin', axis=1, inplace=True)
original_data.drop('Embarked', axis=1, inplace=True)
original_data.info()
# Out:
# 只保留所需的5个变量:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 34.9+ KB

# %%
null_sum = original_data.isnull().sum() #检验是否有缺失值
print(null_sum)
print('由上述得知，年纪缺失177条记录')
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# dtype: int64
# 由上述得知，年纪缺失177条记录

# %% [markdown]
# ##### 3.2.对缺失的字段记录（年纪）进行处理

# %%
# Age
age_data = original_data[['Age','Survived']]
age_is_null = pd.isnull(age_data['Age'])
age_data_without_null = age_data[age_is_null == False]
#print(age_data_without_null)

# %% [markdown]
# ## 四、单因素分析
# ### >>样本生还人数与比例

# %%
#总人数
total_num = len(original_data);
#总生还人数
total_survived_num = original_data['Survived'].sum()
#总未生还人数
total_no_survived_num = total_num - total_survived_num

# 图表
plt.figure(figsize = (10,5))
plt.subplot(121)
# 柱状图
sns.countplot(x='Survived', data=original_data)
#table
table_vals = [[total_num,total_survived_num,total_no_survived_num]]
col_labels = ['total','total survived','total no survived']
row_labels = ['num']
table=plt.table(cellText=table_vals,
      rowLabels=row_labels,
      colLabels=col_labels,colWidths=[0.1]*3,
      loc='bottom',bbox=[0, -0.4, 1, 0.15])
table.set_fontsize(24)
table.scale(10, 10)

plt.title('Survived Count')

plt.subplot(122)
explode = (0,0.07)
plt.pie([total_no_survived_num, total_survived_num],labels=['No Survived','Survived'],explode= explode,autopct='%1.1f%%')
plt.title('Survived Rate') 

plt.show()

# %% [markdown]
# #### 左侧图形（Survived Count）表示：
# 在样本数据中，总样本人数为891，其中生还人数342，未生还人数549
# #### 右侧图形（Survived Rate）表示：
# 在样本数据中，生还人数占总体人数的38.4%，未生还人数占总样本人数的的61.6%

# %% [markdown]
# ### >>年纪对生还率的影响？
# 当前样本数据中已经剔除空值的数据，其样本量为714

# %% [markdown]
# ### 1.1 年纪的分布

# %%
#print(len(age_data_without_null))
# 平均年纪（去掉空值的数据）
# 等同于 mean_age age_data.mean() 类库会自动过滤掉空值
mean_age = age_data_without_null['Age'].mean()
print(mean_age)

#高斯分布 （正态分布） 
fig,ax0 = plt.subplots(nrows=1,figsize=(15,5))  

#第二个参数是柱子宽一些还是窄一些，越大越窄越密  
ax0.hist(age_data_without_null['Age'],50,normed=1,histtype='bar',facecolor='yellowgreen',alpha=0.75)  
##pdf概率分布图  
ax0.set_title('Age - Normal distribution')
# age_data_without_null.groupby(['Age']).count().unstack().plot(kind='bar',stacked='true')
# ax1.hist(age_data_without_null,50,normed=1,histtype='bar',facecolor='pink',alpha=0.75,cumulative=True,rwidth=0.8)  
# #cdf累计概率函数
# ax1.set_title("age - cdf")
# fig.subplots_adjust(hspace=0.4)
plt.show()
# Out:
# 29.6991176471

# %% [markdown]
# #### 上图可知：
# 样本中年纪的分布于19～34岁,平均年龄为30岁

# %% [markdown]
# ### 1.2.年纪与生存率

# %%
#print(age_data_without_null)
age_data_without_null.groupby(['Age','Survived'])['Survived'].count().unstack().plot.bar(stacked=True,figsize=(20,10));

# %% [markdown]
# #### 上图可知
# 16岁～36岁的生还率都接近了45%
# 45岁以后，生还率降低

# %% [markdown]
# ## >>性别对生还率的影响？
# ### 性别与生还率

# %%
original_data.groupby(['Sex','Survived'])['Survived'].count().unstack().plot.bar(stacked=True,figsize=(20,8));

# %% [markdown]
# #### 有上图可知
# 女性的生还率要大于男性生还率

# %% [markdown]
# ## >>不同客舱等级对生还率是否影响？

# %% [markdown]
# ### 1.1 不同级别客舱的人数和比例

# %%
# 不同级别客舱的人数和比例

# 图表
plt.figure(figsize= (10,5))
plt.subplot(121)
#柱状图
sns.countplot(x='Pclass', data=original_data)
plt.title('Pclass Count') 

plt.subplot(122)
explode = (0.1,0,0)
# 不同级别客舱的人数和比例
survived_pclass_rate = original_data[['Pclass','Survived']].groupby(['Pclass']).count();
print(survived_pclass_rate)
plt.pie(survived_pclass_rate,explode=explode,
        labels=['Pclass-1','Pclass-2','Pclass-3'],autopct='%1.1f%%')
plt.title('The survival rate in the Pclass population') 

plt.show()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %% [markdown]
# #### 左侧图形（Pclass Count）表示：
# 在样本数据中，一等舱（pClass-1）的数量为216，二等舱（pClass-2）的数量为184，三等舱（pClass-3）的数量为491。
# #### 右侧图形（The survival rate in the Pclass population）表示：
# 在样本数据中，一等舱的数量占总体舱等数量的24.2%，二等舱的数量占总体舱等数量的20.7%，三等舱的数量占总体舱等数量的55.1%。

# %% [markdown]
# ### 1.2 不同级别客舱生还人数和占总生还人数的比例

# %%
survived_data = original_data[original_data[ 'Survived'] == 1 ]
sum_survived_data = survived_data[['Pclass','Survived']].groupby(['Pclass']).sum()
print(sum_survived_data)

plt.figure(figsize= (10, 5))

plt.subplot(121)
sns.countplot(x='Pclass', data=survived_data)
plt.title('Pclass Survived count') 
plt.ylabel('Survived Count')

plt.subplot(122)
explode=[0.1,0,0]
plt.pie(sum_survived_data,
        labels=['Pclass-1','Pclass-2','Pclass-3'],explode=explode,autopct='%1.1f%%')
plt.title('pclass survival rate in the survival population');
plt.show()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %% [markdown]
# #### 左侧图形（Pclass Survived count）表示：
# 在样本数据中，一等舱（pClass-1）的生还人数为136，二等舱（pClass-2）的生还人数为87，三等舱（pClass-3）的生还人数为119。
# #### 右侧图形（pclass survival rate in the survival population）表示：
# 在样本数据中，一等舱的生还人数占总体生还人数的39.8%，二等舱的生还人数占总体生还人数的20.7%，三等舱的生还人数占总体生还人数的55.1%。

# %% [markdown]
# ### 3.3 不同舱等对应的生还、未生还人数及舱等的生还率

# %% [markdown]
# #### 3.3.1 基于pClass-1的总数的生还与未生还

# %%
# 不同舱等对应的生还和未生还人数及生还率
pclass1 = original_data[original_data['Pclass'] == 1]

plt.figure(figsize=(10,5))

plt.subplot(121)
sns.countplot(x = 'Survived', data = pclass1)
plt.title('Pclass 1 : "No Survived" and "Survived"') 

plt.subplot(122)
pclass1_total = pclass1['Survived'].count()
pclass1_no_survived_total = pclass1['Survived'][pclass1['Survived'] == 0].count()
pclass1_survived_total = pclass1['Survived'][pclass1['Survived'] == 1].count()
print([pclass1_total,pclass1_survived_total,pclass1_no_survived_total])
       
plt.pie([pclass1_no_survived_total,
         pclass1_survived_total],
        labels=['No Survived', 'Survived'],autopct='%1.1f%%')
plt.title('Pclass 1 : "No Survived" and "Survived" rate')

plt.show()
# Out:
# [216, 136, 80]

# %% [markdown]
# #### 左图（Pclass 1 "No Survived" and "Survived"）：
# 一等舱（pClass-1）：总数 136人，未生还 80人，生还 136人
# #### 左图（Pclass 1 "No Survived" and "Survived" rate）：
# 一等舱（pClass-1）其中生还人数占一等舱总人数的63%，未生还人数占一等舱总人数的37%

# %%
pclass2 = original_data[original_data['Pclass'] == 2]

plt.figure(figsize=(10,5))
plt.subplot(121)
sns.countplot(x = 'Survived', data = pclass2)
plt.title('Pclass 2 : "No Survived" and "Survived"') 

plt.subplot(122)
pClass2_total = pclass2['Survived'].count()
pClass2_no_Survived_total = pclass2['Survived'][pclass2['Survived'] == 0].count()
pClass2_Survived_total = pclass2['Survived'][pclass2['Survived'] == 1].count()
print([pClass2_total,pClass2_no_Survived_total,pClass2_Survived_total])
plt.pie([pClass2_no_Survived_total,pClass2_Survived_total],
        labels=['No Survived', 'Survived'],autopct='%1.1f%%')
plt.title('Pclass 2 : "No Survived" and "Survived" rate')

plt.show()
# Out:
# [184, 97, 87]

# %% [markdown]
# #### 左图（Pclass 2 "No Survived" and "Survived"）：
# 二等舱（pClass-2）：总数 184人，未生还 97人，生还 87人
# #### 左图（Pclass 2 "No Survived" and "Survived" rate）：
# 二等舱（pClass-2）其中生还人数占二等舱总人数的52.7%，未生还人数占二等舱总人数的52.7%

# %%
pclass3 = original_data[original_data['Pclass'] == 3]

plt.figure(figsize=(10,5))
plt.subplot(121)
sns.countplot(x = 'Survived', data = pclass3)
plt.title('Pclass 3 : "No Survived" and "Survived"') 

plt.subplot(122)
pclass3_total = pclass3['Survived'].count()
pclass3_no_survived_total = pclass3['Survived'][pclass3['Survived'] == 0].count()
pclass3_survived_total = pclass3['Survived'][pclass3['Survived'] == 1].count()
print([pclass3_total,pclass3_no_survived_total,pclass3_survived_total])
plt.pie([pclass3_no_survived_total,pclass3_survived_total],
        labels=['No Survived', 'Survived'],autopct='%1.1f%%')
plt.title('Pclass 3 : "No Survived" and "Survived" rate')
plt.show()
# Out:
# [491, 372, 119]

# %% [markdown]
# #### 左图（Pclass 3 "No Survived" and "Survived"）：
# 三等舱（pClass-3）：总数 491人，未生还 372人，生还 119人
# #### 左图（Pclass 3 "No Survived" and "Survived" rate）：
# 三等舱（pClass-3）其中生还人数占三等舱总人数的24.2%，未生还人数占三等舱总人数的75.8%

# %% [markdown]
# ## 不同舱等对应的生还平均人数

# %%
plt.figure(figsize=(10,5))

plt.subplot(111)
survived_by_pclass = original_data.groupby('Pclass')['Survived'].mean()
print(survived_by_pclass)
survived_by_pclass.plot(kind = 'bar')
plt.ylabel("Average survival")
plt.title("pClass Average survival")

# plt.subplot(122)
# original_data.groupby(['Pclass','Survived'])['Survived'].count().unstack().plot(kind='bar',stacked='true')

plt.show()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# #### 上图可知：
# + 一等舱的平均生还人数为 0.629630
# + 二等舱的平均生还人数为 0.472826
# + 三等舱的平均生还人数为 0.242363

# %% [markdown]
# ## 五、多因素分析

# %%
#age_is_null = pd.isnull(age_data['Age'])
original_data = original_data[age_is_null == False]
print(len(original_data))
# Out:
# 714

# %% [markdown]
# ### 性别和客舱等级共同对生还率的影响

# %%
#按'Sex','Pclass'对乘客进行分组后每个组的人数
group_all= original_data.groupby(['Sex','Pclass']).count()
#按'Sex','Pclass'对乘客进行分组后每个组生还者的人数
group_survived_value=original_data[original_data['Survived']==1].groupby(['Sex','Pclass']).count()
#按'Sex','Pclass'对乘客进行分组后，每组生还者的概率
result =  group_survived_value/group_all
result.plot.area(stacked=True,figsize=(20,8),title='Sex Pclass Survived');

# %% [markdown]
# #### 上图所示，对生还率的影响
# + 性别>客舱等级，
# + 其次是客舱等级对生还率的影响是1>2>3

# %% [markdown]
# ### 性别和年纪对生还率的影响

# %%
sex_age_data=original_data[['Age','Sex']]
sex_age_Survived_data=original_data[['Age','Sex']][original_data['Survived']==1]

#每组生还者的人数
sex_age_groupby_survived=sex_age_Survived_data.groupby(['Sex','Age'])['Sex'].count()
#每组的总人数
sex_age_groupby_survived_all=sex_age_data.groupby(['Sex','Age'])['Sex'].count()

result= sex_age_groupby_survived/sex_age_groupby_survived_all
result.plot.area(stacked=True,figsize=(20,10),title="sex and age");

# %% [markdown]
# #### 上图得知：
# + 对生还率影响大的是性别，女性>男性。
# + 年纪：幼儿>16～38>38～60

# %% [markdown]
# ### 年龄和乘客等级共同对生还率的影响

# %%
pclass_age_data=original_data[['Pclass','Age']]
pclass_age_Survived_data=original_data[['Pclass','Age']][original_data['Survived']==1]

#每组生还者的人数
pclass_age_groupby_survived=pclass_age_Survived_data.groupby(['Pclass','Age'])['Pclass'].count()
#每组的总人数
pclass_age_groupby_survived_all=pclass_age_data.groupby(['Pclass','Age'])['Pclass'].count()

result= pclass_age_groupby_survived/pclass_age_groupby_survived_all
result.plot.area(stacked=True,figsize=(20,10),title="Pclass and age");

# %% [markdown]
# #### 上图所示：
# + 看出客舱等级对生还率的影响>年龄的影响
# + 年龄（幼儿的存活要高，其次是年龄处于青壮11～35，年纪大的40～70），客舱等级越差生还率越低

# %% [markdown]
# ## 六、结论
# ### 通过分析，可以看出对生还率影响最大的因素是乘客等级，其次是性别，最后年龄段也对生化率有影响
#
# ### 分析的局限性
# 这里并没有从统计上分析得出这些结果的偶然性，所以并不知道这里的结果是真正的差异造成的还是噪音造成的
# 年龄字段有一些缺失值，删除了这些异常样本，也会影响分析结果
# 结果的相关性
# 这里的数据并非通过试验得出，所以无法说自变量之间的因果性，只能说她们之间有相关性
